# %% [markdown]
# ###  Diabetes EDA – PIMA Indians Dataset
#
# This notebook walks through Exploratory Data Analysis (EDA) for the PIMA Indians Diabetes dataset. It is designed to teach how the data behaves before modeling.

# %% [markdown]
# #### 1. Imports & Setup
